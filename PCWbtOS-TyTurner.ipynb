# %%
try:
    import flaml
except:
    ! pip install -U ipywidgets ipython-autotime plotly scikit-learn dask[dataframe] shap chess
path = {'root':'/kaggle'}
path['in' ] = path['root'] + '/input/chess-games/'
path['out'] = path['root'] + '/working'
# Out:
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (8.1.5)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting ipython-autotime
#   Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.1.1-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: shap in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Collecting shap
#   Downloading shap-0.47.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting chess
#   Downloading chess-1.11.2.tar.gz (6.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 53.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dask[dataframe] in /usr/local/lib/python3.10/dist-packages (2024.11.2)
# Collecting dask[dataframe]
#   Downloading dask-2025.5.1-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.7.1)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.10/dist-packages (from plotly) (1.18.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.2)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2024.9.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (0.12.1)
# Requirement already satisfied: importlib_metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (8.5.0)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (2.2.3)
# Requirement already satisfied: pyarrow>=14.0.1 in /usr/local/lib/python3.10/dist-packages (from dask[dataframe]) (19.0.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.67.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from shap) (4.12.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib_metadata>=4.13.0->dask[dataframe]) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (75.1.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.48)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.19.5->scikit-learn) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.0->dask[dataframe]) (2025.1)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask[dataframe]) (1.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->dask[dataframe]) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.5->scikit-learn) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.19.5->scikit-learn) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.19.5->scikit-learn) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.19.5->scikit-learn) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.19.5->scikit-learn) (2024.2.0)
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 6.4 MB/s eta 0:00:00
# Downloading ipython_autotime-0.3.2-py2.py3-none-any.whl (7.0 kB)
# Downloading plotly-6.1.1-py3-none-any.whl (16.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 71.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 75.1 MB/s eta 0:00:00
# Downloading shap-0.47.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (992 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 992.3/992.3 kB 30.2 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 kB 10.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 59.5 MB/s eta 0:00:00
# Downloading dask-2025.5.1-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 45.0 MB/s eta 0:00:00
# Building wheels for collected packages: chess
#   Building wheel for chess (setup.py) ... done
#   Created wheel for chess: filename=chess-1.11.2-py3-none-any.whl size=147776 sha256=7befb733ac1ee81be2b283e7db3fd5b11a4c2ac55ce0c59027eced39dcaf391a
#   Stored in directory: /root/.cache/pip/wheels/7a/79/8e/0d6e404db9f1e82af2e40b49161d6acab485d75dfb0470ac08
# Successfully built chess
# Installing collected packages: widgetsnbextension, slicer, plotly, jupyterlab_widgets, chess, dask, ipywidgets, ipython-autotime, scikit-learn, shap
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.13
#     Uninstalling widgetsnbextension-4.0.13:
#       Successfully uninstalled widgetsnbextension-4.0.13
#   Attempting uninstall: slicer
#     Found existing installation: slicer 0.0.7
#     Uninstalling slicer-0.0.7:
#       Successfully uninstalled slicer-0.0.7
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: jupyterlab_widgets
#     Found existing installation: jupyterlab_widgets 3.0.13
#     Uninstalling jupyterlab_widgets-3.0.13:
#       Successfully uninstalled jupyterlab_widgets-3.0.13
#   Attempting uninstall: dask
#     Found existing installation: dask 2024.11.2
#     Uninstalling dask-2024.11.2:
#       Successfully uninstalled dask-2024.11.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.5
#     Uninstalling ipywidgets-8.1.5:
#       Successfully uninstalled ipywidgets-8.1.5
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: shap
#     Found existing installation: shap 0.44.1
#     Uninstalling shap-0.44.1:
#       Successfully uninstalled shap-0.44.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# category-encoders 2.7.0 requires scikit-learn<1.6.0,>=1.0.0, but you have scikit-learn 1.6.1 which is incompatible.
# dask-expr 1.1.19 requires dask==2024.11.2, but you have dask 2025.5.1 which is incompatible.
# distributed 2024.11.2 requires dask==2024.11.2, but you have dask 2025.5.1 which is incompatible.
# rapids-dask-dependency 24.12.0 requires dask==2024.11.2, but you have dask 2025.5.1 which is incompatible.
# Successfully installed chess-1.11.2 dask-2025.5.1 ipython-autotime-0.3.2 ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 plotly-6.1.1 scikit-learn-1.6.1 shap-0.47.2 slicer-0.0.8 widgetsnbextension-4.0.14

# %%
##################################################################
### Setup and Read in chess_games
import sklearn as sk, sklearn.base, sklearn.model_selection, sklearn.preprocessing, sklearn.compose, sklearn.ensemble, sklearn.pipeline, sklearn.inspection
import pickle, shap, plotly.express as px, pandas as pd, numpy as np, chess, chess.engine, seaborn as sns, re, matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import MDS
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

seed = 42
sk.set_config(transform_output="pandas")
df =  pd.read_csv(path['in'] + 'chess_games.csv')

# %%
df.head()
# Out:
#                 Event            White       Black Result     UTCDate  \
# 0          Classical           eisaaaa    HAMID449    1-0  2016.06.30
# 1              Blitz            go4jas  Sergei1973    0-1  2016.06.30
# 2   Blitz tournament   Evangelistaizac      kafune    1-0  2016.06.30
# 3     Correspondence            Jvayne    Wsjvayne    1-0  2016.06.30
# 4   Blitz tournament            kyoday   BrettDale    0-1  2016.06.30
#
#     UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  ECO  \
# 0  22:00:01      1901      1896             11.0            -11.0  D10
# 1  22:00:01      1641      1627            -11.0             12.0  C20
# 2  22:00:02      1647      1688             13.0            -13.0  B01
# 3  22:00:02      1706      1317             27.0            -25.0  A00
# 4  22:00:02      1945      1900            -14.0             13.0  B90
#
#                                          Opening TimeControl   Termination  \
# 0                                   Slav Defense       300+5  Time forfeit
# 1                      King's Pawn Opening: 2.b3       300+0        Normal
# 2  Scandinavian Defense: Mieses-Kotroc Variation       180+0  Time forfeit
# 3                           Van't Kruijs Opening           -        Normal
# 4    Sicilian Defense: Najdorf, Lipnitsky Attack       180+0  Time forfeit
#
#                                                   AN
# 0  1. d4 d5 2. c4 c6 3. e3 a6 4. Nf3 e5 5. cxd5 e...
# 1  1. e4 e5 2. b3 Nf6 3. Bb2 Nc6 4. Nf3 d6 5. d3 ...
# 2  1. e4 d5 2. exd5 Qxd5 3. Nf3 Bg4 4. Be2 Nf6 5....
# 3  1. e3 Nf6 2. Bc4 d6 3. e4 e6 4. Nf3 Nxe4 5. Nd...
# 4  1. e4 c5 2. Nf3 d6 3. d4 cxd4 4. Nxd4 Nf6 5. N...

# %%
#Bar plot Defintion

def check_missing_vals(df):
    """
    Generates a report of missing values for each column in the DataFrame.

    Parameters:
        df (pd.DataFrame): The DataFrame to check for missing values.

    Returns:
        pd.DataFrame: A DataFrame containing columns with missing values and their statistics.
    """
    # Check for null values in each column
    missing_values_report = df.isnull().sum()

    # Create a DataFrame for the missing values report
    missing_values_df = pd.DataFrame({
        'Missing Values': missing_values_report.values,
        'Total Rows': len(df),
        'Missing Percentage': (missing_values_report / len(df)) * 100
    })

    # Filter out columns with no missing values
    columns_with_missing = missing_values_df[missing_values_df['Missing Values'] > 0]

    # Print the table
    print("Missing Values Report:\n")
    if  columns_with_missing.empty:
        #print("No columns have missing values.")
        return "No columns have missing values."
        #print(columns_with_missing.to_string(index=False, float_format="%.2f"))

    # Return the DataFrame for further use if needed
    return columns_with_missing
    
def plot_top_10_levels(df, columns):
    """
    Creates bar plots for the specified columns in the DataFrame, showing only the top 10 levels.
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        columns (list): List of columns for which to create bar plots.
    """
    for column in columns:
        # Count the frequency of each level and get the top 10
        top_10 = df[column].value_counts()[:10]

        # Plot the bar chart
        plt.figure(figsize=(17, 10))  # Larger figure for readability
        bars = top_10.plot(kind='bar', color='skyblue', edgecolor='black')

        # Add counts above each bar
        for idx, count in enumerate(top_10.values):
            plt.text(idx, count + count * 0.02, f'{count:,}', ha='center', va='bottom', 
                     fontsize=10, fontweight='bold', color='black')  # Add thousands separator

        # Title and labels
        if len(df[column].unique()) > 10:
            plt.title(f"Top 10 Levels for '{column}' with {len(df[column].unique())} total levels.", fontsize=16, fontweight='bold')
        else:
            plt.title(f"{len(df[column].unique())} Levels of '{column}'", fontsize=16, fontweight='bold')
        plt.ylabel("Frequency", fontsize=14, fontweight='bold')

        # Remove the x-axis label
        plt.xlabel("")

        # Rotate x-ticks for readability
        plt.xticks(rotation=45, ha='right', fontsize=12)

        # Add a grid to improve readability
        plt.grid(axis='y', linestyle='--', alpha=0.7)

        # Adjust layout to avoid labels being cut off
        plt.tight_layout()

        # Show the plot
        plt.show()

def analyze_quantitative_column(df, column):
    """
    Analyzes a quantitative column in the DataFrame with the following steps:
    - Plots a histogram or KDE with log transformations if necessary.
    - Computes a six-number summary (min, Q1, Q2/median, Q3, max, mean).
    - Counts the number of missing values.
    - Screens data for potential errors (e.g., negative values or outliers).
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        column (str): The name of the column to analyze.
    """
    # Step 1: Handle missing values
    # missing_count = df[column].isnull().sum()
    # total_count = len(df[column])
    
    # print(f"Analysis for '{column}':")
    # print(f"Total Rows: {total_count}")
    # print(f"Missing Values: {missing_count} ({(missing_count / total_count) * 100:.2f}%)\n")
    
    # Step 2: Compute six-number summary
    summary = df[column].describe(percentiles=[0.25, 0.5, 0.75])
    six_number_summary = pd.DataFrame({
        "Statistic": ["Min", "Q1 (25%)", "Median (Q2)", "Q3 (75%)", "Max", "Mean"],
        "Value": [
            summary['min'],
            summary['25%'],
            summary['50%'],
            summary['75%'],
            summary['max'],
            summary['mean']
        ]
    })
    
    # Print the six-number summary as a table
    print("Six-Number Summary:")
    print(six_number_summary.to_string(index=False, float_format="%.2f"))

    # Step 3: Screen for errors
    potential_errors = df[(df[column] < 0)]
    if not potential_errors.empty:
        print("\nPotential Errors Detected: Negative values found")
    else:
        print("\nNo negative values detected")

    # Step 4: Plot histogram or KDE
    plt.figure(figsize=(12, 8))
    column_data = df[column].dropna()  # Drop missing values for plotting

    if column_data.skew() > 1 or column_data.min() <= 0:
        # Apply log-modulus transform to handle skewness or zero/negative values
        transformed_data = np.sign(column_data) * np.log1p(np.abs(column_data))
        sns.histplot(transformed_data, kde=True, color='skyblue', edgecolor='black')
        plt.title(f"Histogram & KDE for '{column}' (Log-Modulus Transformed)")
        plt.xlabel(f"Log-Modulus Transformed {column}")
    else:
        # Plot without transformation
        sns.histplot(column_data, kde=True, color='skyblue', edgecolor='black')
        plt.title(f"Histogram & KDE for '{column}'")
        plt.xlabel(column)

    plt.ylabel("Frequency")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

def analyze_quantitative_column_raw(df, column):
    """
    Analyzes a quantitative column in the DataFrame without log transformations.
    - Plots a histogram and KDE of the raw data.
    - Computes a six-number summary (min, Q1, median, Q3, max, mean).
    - Counts the number of missing values.
    - Screens data for potential issues (e.g., negative values or extreme outliers).
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        column (str): The name of the column to analyze.
    """
    column_data = df[column].dropna()
    total_count = len(df[column])
    missing_count = df[column].isnull().sum()

    print(f"Analysis for '{column}':")
    print(f"Total Rows: {total_count}")
    print(f"Missing Values: {missing_count} ({(missing_count / total_count) * 100:.2f}%)\n")

    # Step 1: Summary statistics
    summary = column_data.describe(percentiles=[0.25, 0.5, 0.75])
    six_number_summary = pd.DataFrame({
        "Statistic": ["Min", "Q1 (25%)", "Median (Q2)", "Q3 (75%)", "Max", "Mean"],
        "Value": [
            summary['min'],
            summary['25%'],
            summary['50%'],
            summary['75%'],
            summary['max'],
            summary['mean']
        ]
    })

    print("Six-Number Summary:")
    print(six_number_summary.to_string(index=False, float_format="%.2f"))

    # Step 2: Check for negative values
    if (column_data < 0).any():
        print("\nPotential Issues: Negative values found")
    else:
        print("\nNo negative values detected")

    # Step 3: Histogram + KDE (no transformation)
    plt.figure(figsize=(12, 8))
    sns.histplot(column_data, kde=True, color='cornflowerblue', edgecolor='black')
    plt.title(f"Histogram & KDE for '{column}' (Raw Data)")
    plt.xlabel(column)
    plt.ylabel("Frequency")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()
    
#Translating AN to an aggregate score
from concurrent.futures import ProcessPoolExecutor
def parse_chess_moves(algebraic_str):
    """
    Parses a string of algebraic chess notation and converts it into a dictionary.
    :param algebraic_str: str, algebraic chess notation (e.g., "1. c4 c3 2. d4 d3")
    :return: dict, {move_number: (white_move, black_move)}
    """
    move_dict = {}
    moves = re.findall(r'\d+\.\s*([\w+#=-]+)\s*([\w+#=-]*)', algebraic_str)
    
    for i, (white, black) in enumerate(moves, start=1):
        move_dict[i] = (white, black if black else None)
    
    return move_dict

def process_dataframe(df, column_name):
    """
    Applies the parse_chess_moves function to a DataFrame column.
    :param df: pandas DataFrame containing chess notation data
    :param column_name: str, name of the column to process
    :return: pandas DataFrame with a new column 'parsed_moves'
    """
    df['parsed_moves'] = df[column_name].apply(parse_chess_moves)
    return df

def reconstruct_chess_moves(parsed_moves, max_moves = 5):
    """
    Reconstructs algebraic notation from a parsed dictionary, truncating at max_moves.
    :param parsed_moves: dict, parsed chess moves
    :param max_moves: int, maximum number of moves to include
    :return: str, reconstructed algebraic notation
    """
    reconstructed = []
    for i in range(1, max_moves + 1):
        if i in parsed_moves:
            white, black = parsed_moves[i]
            move_str = f"{i}. {white}"
            if black:
                move_str += f" {black}"
            reconstructed.append(move_str)
    return " ".join(reconstructed)
###############################################################################################
def divergence_ply(seq1, seq2):
    """
    Counts the total number of differing plies (half-moves) between two sequences.
    Includes differences due to unequal lengths.
    """
    min_len = min(len(seq1),len(seq2))
    #min_len = min(len(seq1),len(seq2))
    #np.sum(seq1[0:min_len] != seq2[0:min_len])
    #Boolean_series = (seq1[0:min_len] != seq2[0:min_len]

    for i in range(min_len):
        move1 = seq1[i]
        move2 = seq2[i]
        if move1 != move2: #np.sum(seq1[0:min_len] != seq2[0:min_len]):
            return i+1
    return min_len

def compute_distance_matrix(parsed_moves):
    """
    Computes a distance matrix based on how early sequences diverge.
    D(seq1, seq2) = 1 / (n^2 + 1) where n is the first ply where they differ.
    """
    n = len(parsed_moves)
    dist_matrix = np.zeros((n, n))
    for i in range(n):
        for j in range(i + 1, n):
            n_div = divergence_ply(parsed_moves[i], parsed_moves[j])
            dist = 1 / (n_div^2)
            dist_matrix[i][j] = dist
            dist_matrix[j][i] = dist
        if i%1000 == 0:
            print('we are on ', i, ' row number.')
    return dist_matrix
###############################################################################################

def plot_elbow_method(data, max_k=20):
    """
    Plots the Elbow Method for KMeans clustering.
    """
    distortions = []
    K = range(1, max_k + 1)
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(data)
        distortions.append(kmeans.inertia_)

    plt.figure(figsize=(8, 5))
    plt.plot(K, distortions, 'bo-')
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('Inertia (Distortion)')
    plt.title('Elbow Method For Optimal k')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

def plot_silhouette_scores(data, max_k=20):
    """
    Plots silhouette scores for different values of k.
    """
    silhouette_scores = []
    K = range(2, max_k + 1)  # Silhouette score is undefined for k=1
    for k in K:
        kmeans = KMeans(n_clusters=k, random_state=42)
        labels = kmeans.fit_predict(data)
        score = silhouette_score(data, labels)
        silhouette_scores.append(score)

    plt.figure(figsize=(8, 5))
    plt.plot(K, silhouette_scores, 'go-')
    plt.xlabel('Number of Clusters (k)')
    plt.ylabel('Silhouette Score')
    plt.title('Silhouette Method For Optimal k')
    plt.grid(True)
    plt.tight_layout()
    plt.show()

###############################################################################################

def analyze_timecontrol_column(df, column):
    """
    Analyzes a quantitative column in the DataFrame with the following steps:
    - Plots a histogram or KDE with log transformations if necessary.
    - Computes a six-number summary (min, Q1, Q2/median, Q3, max, mean).
    - Counts the number of missing values.
    - Screens data for potential errors (e.g., negative values or outliers).
    
    Parameters:
        df (pd.DataFrame): The DataFrame to analyze.
        column (str): The name of the column to analyze.
    """
    # Step 1: Handle missing values
    # missing_count = df[column].isnull().sum()
    # total_count = len(df[column])
    
    # print(f"Analysis for '{column}':")
    # print(f"Total Rows: {total_count}")
    # print(f"Missing Values: {missing_count} ({(missing_count / total_count) * 100:.2f}%)\n")
    
    # Step 2: Compute six-number summary
    summary = df[column].describe(percentiles=[0.25, 0.5, 0.75])
    six_number_summary = pd.DataFrame({
        "Statistic": ["Min", "Q1 (25%)", "Median (Q2)", "Q3 (75%)", "Max", "Mean"],
        "Value": [
            summary['min'],
            summary['25%'],
            summary['50%'],
            summary['75%'],
            summary['max'],
            summary['mean']
        ]
    })
    
    # Print the six-number summary as a table
    print("Six-Number Summary:")
    print(six_number_summary.to_string(index=False, float_format="%.2f"))

    # Step 3: Screen for errors
    potential_errors = df[(df[column] < 0)]
    if not potential_errors.empty:
        print("\nPotential Errors Detected: Negative values found")
    else:
        print("\nNo negative values detected")

# %%
# Feature Engineering 
#Initializes our target variable and reduces our dataset from 6m+ to a variable rows
target_column = 'Result'
rows = 10000
chess_df = df.copy(deep = True)
chess_df = chess_df[chess_df['Result'] != '1/2-1/2']
chess_df = chess_df[:rows]

#Gets rid of leading and trailing whitespace
chess_df['Event'] = chess_df['Event'].str.strip()

#fills in missing values from WhiteRatingDiff and BlackRatingDiff
#chess_df['WhiteRatingDiff'].fillna(chess_df['WhiteRatingDiff'].median(), inplace=True)
chess_df.fillna({'WhiteRatingDiff': chess_df['WhiteRatingDiff'].median()},inplace = True)
chess_df.fillna({'BlackRatingDiff': chess_df['BlackRatingDiff'].median()},inplace = True)

#Ignores the buffer time at the end of a usual TimeControl variable to make the data easier to parse
chess_df['TimeControl'] = pd.to_numeric(chess_df['TimeControl'].str.split("+", expand=True)[0], errors='coerce')
chess_df.fillna({'TimeControl': 0},inplace = True)

#Processes our AN-move set variable to remove any moves past turn 15.
tmp = process_dataframe(chess_df, 'AN')
chess_df['parsed_moves'] = tmp['parsed_moves'].apply(lambda moves: reconstruct_chess_moves(moves, max_moves=15))
#chess_df['AN_opening'] = tmp['parsed_moves'].apply(lambda moves: reconstruct_chess_moves(moves, max_moves=5))

chess_df['EloDiff'] = chess_df['WhiteElo'] - chess_df['BlackElo']

# %%
# Parse the AN (algebraic notation) column into move sequences
#chess_df['parsed_moves'] = chess_df['AN'].apply(parse_chess_moves)

# Compute distance matrix from parsed moves
dist_matrix = compute_distance_matrix(chess_df['parsed_moves'].tolist())

sil_scores = []
K_range = range(2, 50)

for k in K_range:
    model = AgglomerativeClustering(n_clusters=k, metric='precomputed', linkage='average')
    labels = model.fit_predict(dist_matrix)
    score = silhouette_score(dist_matrix, labels, metric='precomputed')
    sil_scores.append(score)
    print(f"Silhouette score for k={k}: {score:.4f}")

# Plot silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(K_range, sil_scores, marker='o')
plt.title("Silhouette Score vs. Number of Clusters")
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.grid(True)
plt.show()

#testing optimal K
# Out:
# we are on  0  row number.
# we are on  1000  row number.
# we are on  2000  row number.
# we are on  3000  row number.
# we are on  4000  row number.
# we are on  5000  row number.
# we are on  6000  row number.
# we are on  7000  row number.
# we are on  8000  row number.
# we are on  9000  row number.
# Silhouette score for k=2: 0.1838
# Silhouette score for k=3: 0.2022
# Silhouette score for k=4: 0.2211
# Silhouette score for k=5: 0.2209
# Silhouette score for k=6: 0.2380
# Silhouette score for k=7: 0.2564
# Silhouette score for k=8: 0.2541
# Silhouette score for k=9: 0.2626
# Silhouette score for k=10: 0.2724
# Silhouette score for k=11: 0.2777
# Silhouette score for k=12: 0.3561
# Silhouette score for k=13: 0.3634
# Silhouette score for k=14: 0.3895
# Silhouette score for k=15: 0.3924
# Silhouette score for k=16: 0.3958
# Silhouette score for k=17: 0.3995
# Silhouette score for k=18: 0.4005
# Silhouette score for k=19: 0.4042
# Silhouette score for k=20: 0.4138
# Silhouette score for k=21: 0.4233
# Silhouette score for k=22: 0.4261
# Silhouette score for k=23: 0.4335
# Silhouette score for k=24: 0.4346
# Silhouette score for k=25: 0.4390
# Silhouette score for k=26: 0.4406
# Silhouette score for k=27: 0.4432
# Silhouette score for k=28: 0.4438
# Silhouette score for k=29: 0.4454
# Silhouette score for k=30: 0.4464
# Silhouette score for k=31: 0.4466
# Silhouette score for k=32: 0.4469
# Silhouette score for k=33: 0.4478
# Silhouette score for k=34: 0.4478
# Silhouette score for k=35: 0.4489
# Silhouette score for k=36: 0.4502
# Silhouette score for k=37: 0.4533
# Silhouette score for k=38: 0.4544
# Silhouette score for k=39: 0.4547
# Silhouette score for k=40: 0.4552
# Silhouette score for k=41: 0.4553
# Silhouette score for k=42: 0.4555
# Silhouette score for k=43: 0.4557
# Silhouette score for k=44: 0.4557
# Silhouette score for k=45: 0.4560
# Silhouette score for k=46: 0.4562
# Silhouette score for k=47: 0.4562
# Silhouette score for k=48: 0.4564
# Silhouette score for k=49: 0.4564

# %%
#kmeans = KMeans(n_clusters=9, random_state=seed)
#clusters = kmeans.fit_predict(coords)
model = AgglomerativeClustering(n_clusters=17, metric='precomputed', linkage='average')
clusters = model.fit_predict(dist_matrix)
# Add cluster labels to your DataFrame
chess_df['AN_cluster'] = clusters

# View results
print(chess_df[['AN', 'AN_cluster']].head())
# Out:
#                                                   AN  AN_cluster
# 0  1. d4 d5 2. c4 c6 3. e3 a6 4. Nf3 e5 5. cxd5 e...          11
# 1  1. e4 e5 2. b3 Nf6 3. Bb2 Nc6 4. Nf3 d6 5. d3 ...          14
# 2  1. e4 d5 2. exd5 Qxd5 3. Nf3 Bg4 4. Be2 Nf6 5....          12
# 3  1. e3 Nf6 2. Bc4 d6 3. e4 e6 4. Nf3 Nxe4 5. Nd...           5
# 4  1. e4 c5 2. Nf3 d6 3. d4 cxd4 4. Nxd4 Nf6 5. N...           3

# %%
check_missing_vals(chess_df)
# Out:
# Missing Values Report:
# 'No columns have missing values.'

# %%
#Splitting Total Data, 80% Training Dataset, 20% Holdout Dataset

# First split: 80% training, 20% holdout
training_set, holdout_set = train_test_split(chess_df, test_size=0.2, random_state=seed, stratify=chess_df[target_column])

#Splitting Training data, 80% training, 20% testing
X = training_set.drop(columns=target_column)
y = training_set[target_column]

# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# Calculate row counts and percentages
total_rows = len(X)
train_percentage = (len(X_train) / total_rows) * 100
test_percentage = (len(X_test) / total_rows) * 100

split_report_df = pd.DataFrame({
    'Row Count': [len(X_train), len(X_test)],
    'Percentage of Total': [f"{train_percentage:.2f}%", f"{test_percentage:.2f}%"],
    'Features (X)': [X_train.shape, X_test.shape],
    'Target (y)': [(len(y_train), 1), (len(y_test), 1)]
}, index=['Training Set', 'Holdout Set'])

# Print the report
print("Data Split Report:\n")
print(split_report_df.to_string(index=True, float_format="%.2f"))
# Out:
# Data Split Report:
#
#               Row Count Percentage of Total Features (X) Target (y)
# Training Set       6400              80.00%   (6400, 17)  (6400, 1)
# Holdout Set        1600              20.00%   (1600, 17)  (1600, 1)

# %%
#Remove unneccessary Columns and Restructure certain Columns
drop_cols = ['White','Black','WhiteRatingDiff', 'BlackRatingDiff', 'UTCDate','UTCTime','parsed_moves','AN', 'AN_opening','Termination']
categorical_cols = ['Event', 'ECO','Opening']
quantitative_cols = ['WhiteElo','BlackElo','TimeControl', 'EloDiff','AN_cluster']

X_train = X_train.drop(columns=drop_cols, errors='ignore')
X_test = X_test.drop(columns=drop_cols, errors='ignore')

# %%
X_train.head()
# Out:
#           Event  WhiteElo  BlackElo  ECO                           Opening  \
# 7265  Classical      1677      1789  B00               Nimzowitsch Defense
# 761       Blitz      1836      1904  C00  French Defense: Knight Variation
# 5737  Classical      1251      1421  C44                       Scotch Game
# 6594  Classical      1851      2000  A00              Van't Kruijs Opening
# 8164     Bullet      1719      1633  C00  French Defense: Knight Variation
#
#       TimeControl  EloDiff  AN_cluster
# 7265        480.0     -112           2
# 761         180.0      -68           5
# 5737        600.0     -170          14
# 6594        480.0     -149          15
# 8164        120.0       86          14

# %%
#Bar plot of the top 10 levels of Event, if more than 10 add "other" as a category - show missing values

#plot_top_10_levels(X_train,['Event'])

# %%
#Bar plot of the top 10 levels of ECO, if more than 10 add "other" as a category - show missing values
plot_top_10_levels(X_train,['ECO'])

# %%
#Bar plot of the top 10 levels of Opening, if more than 10 add "other" as a category - show missing values
plot_top_10_levels(X_train,['Opening'])

# %%
#Histogram plot of WhiteElo, might need to log-mod or use a kernal density estimator, show 6-number summary (min,q1,q2,q3,max,mean)
analyze_quantitative_column(X_train, 'WhiteElo')
# Out:
# Six-Number Summary:
#   Statistic   Value
#         Min  846.00
#    Q1 (25%) 1547.75
# Median (Q2) 1724.50
#    Q3 (75%) 1901.00
#         Max 2628.00
#        Mean 1727.80
#
# No negative values detected
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Histogram plot of BlackElo, might need to log-mod or use a kernal density estimator, show 6-number summary (min,q1,q2,q3,max,mean)
analyze_quantitative_column(X_train, 'BlackElo')
# Out:
# Six-Number Summary:
#   Statistic   Value
#         Min  877.00
#    Q1 (25%) 1544.75
# Median (Q2) 1722.00
#    Q3 (75%) 1896.00
#         Max 2623.00
#        Mean 1725.90
#
# No negative values detected
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Histogram plot of TimeControl, might need to log-mod or use a kernal density estimator, show 6-number summary (min,q1,q2,q3,max,mean)
#analyze_quantitative_column(X_new, 'TimeControl')
def plot_timecontrol_countplot(df, column='TimeControl'):
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=column, palette="Blues_d")
    plt.title(f"Plot of TimeControl Values", fontsize=14)
    plt.xlabel("TimeControl", fontsize=12)
    plt.ylabel("Count", fontsize=12)
    plt.xticks(rotation=45, ha='right')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

# Assuming you have the 'TimeControl' column
analyze_timecontrol_column(X_train, 'TimeControl')
# Out:
# Six-Number Summary:
#   Statistic    Value
#         Min     0.00
#    Q1 (25%)   120.00
# Median (Q2)   240.00
#    Q3 (75%)   300.00
#         Max 10800.00
#        Mean   326.38
#
# No negative values detected

# %%
#Histogram plot of stockfish_eval_white, might need to log-mod or use a kernal density estimator, show 6-number summary (min,q1,q2,q3,max,mean)
analyze_quantitative_column_raw(X_train, 'AN_cluster')
# Out:
# Analysis for 'AN_cluster':
# Total Rows: 6400
# Missing Values: 0 (0.00%)
#
# Six-Number Summary:
#   Statistic  Value
#         Min   0.00
#    Q1 (25%)   4.00
# Median (Q2)  11.00
#    Q3 (75%)  14.00
#         Max  16.00
#        Mean   8.68
#
# No negative values detected
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Encode target variable
y_train = y_train.map({'1-0': 1, '0-1': 0, '1/2-1/2': -1})
y_test = y_test.map({'1-0': 1, '0-1': 0, '1/2-1/2': -1})

# Check for any NaNs caused by mapping unexpected values
print("y_train unique values:", y_train.unique())
print("Any NaNs in y_train:", y_train.isna().any())
print("number of nans:", y_train.isna().sum())

from catboost import CatBoostClassifier
from sklearn.utils.class_weight import compute_class_weight

# Get unique class labels
classes = np.unique(y_train)

# Compute class weights
class_weights = compute_class_weight(class_weight="balanced", classes=classes, y=y_train)
class_weights_dict = dict(zip(classes, class_weights))

# Initialize CatBoost classifier
cat_model = CatBoostClassifier(iterations=5000, depth=8, learning_rate=0.01, cat_features=categorical_cols, verbose=100,class_weights=list(class_weights_dict.values()))

# Train the model
cat_model.fit(X_train, y_train)

# Make predictions
y_pred = cat_model.predict(X_test)
# Out:
# y_train unique values: [0 1]
# Any NaNs in y_train: False
# number of nans: 0
# 0:	learn: 0.6916284	total: 68.8ms	remaining: 5m 44s
# 100:	learn: 0.6214525	total: 1.11s	remaining: 53.9s
# 200:	learn: 0.6030636	total: 2.14s	remaining: 51.1s
# 300:	learn: 0.5906648	total: 3.18s	remaining: 49.7s
# 400:	learn: 0.5804363	total: 4.25s	remaining: 48.8s
# 500:	learn: 0.5707600	total: 5.3s	remaining: 47.6s
# 600:	learn: 0.5613370	total: 6.32s	remaining: 46.2s
# 700:	learn: 0.5515744	total: 7.35s	remaining: 45s
# 800:	learn: 0.5427187	total: 8.37s	remaining: 43.9s
# 900:	learn: 0.5330241	total: 9.43s	remaining: 42.9s
# 1000:	learn: 0.5226409	total: 10.6s	remaining: 42.2s
# 1100:	learn: 0.5125195	total: 11.7s	remaining: 41.4s
# 1200:	learn: 0.5036495	total: 12.8s	remaining: 40.6s
# 1300:	learn: 0.4948586	total: 14s	remaining: 39.8s
# 1400:	learn: 0.4863401	total: 15.3s	remaining: 39.3s
# 1500:	learn: 0.4776596	total: 16.6s	remaining: 38.6s
# 1600:	learn: 0.4697133	total: 17.7s	remaining: 37.5s
# 1700:	learn: 0.4612536	total: 18.8s	remaining: 36.4s
# 1800:	learn: 0.4533473	total: 19.9s	remaining: 35.3s
# 1900:	learn: 0.4454341	total: 21s	remaining: 34.2s
# 2000:	learn: 0.4384030	total: 22.1s	remaining: 33.1s
# 2100:	learn: 0.4310119	total: 23.2s	remaining: 32s
# 2200:	learn: 0.4239599	total: 24.3s	remaining: 30.9s
# 2300:	learn: 0.4173556	total: 25.4s	remaining: 29.8s
# 2400:	learn: 0.4106865	total: 26.5s	remaining: 28.7s
# 2500:	learn: 0.4045089	total: 27.6s	remaining: 27.6s
# 2600:	learn: 0.3981811	total: 28.7s	remaining: 26.5s
# 2700:	learn: 0.3916224	total: 29.8s	remaining: 25.4s
# 2800:	learn: 0.3858573	total: 30.9s	remaining: 24.3s
# 2900:	learn: 0.3800256	total: 32s	remaining: 23.2s
# 3000:	learn: 0.3745402	total: 33.1s	remaining: 22.1s
# 3100:	learn: 0.3689376	total: 34.3s	remaining: 21s
# 3200:	learn: 0.3633912	total: 35.4s	remaining: 19.9s
# 3300:	learn: 0.3586044	total: 36.5s	remaining: 18.8s
# 3400:	learn: 0.3532087	total: 37.6s	remaining: 17.7s
# 3500:	learn: 0.3485278	total: 38.7s	remaining: 16.6s
# 3600:	learn: 0.3437616	total: 39.8s	remaining: 15.5s
# 3700:	learn: 0.3386173	total: 40.9s	remaining: 14.4s
# 3800:	learn: 0.3338136	total: 42s	remaining: 13.2s
# 3900:	learn: 0.3287567	total: 43.1s	remaining: 12.1s
# 4000:	learn: 0.3245632	total: 44.2s	remaining: 11s
# 4100:	learn: 0.3201328	total: 45.4s	remaining: 9.94s
# 4200:	learn: 0.3155771	total: 46.5s	remaining: 8.85s
# 4300:	learn: 0.3111648	total: 47.8s	remaining: 7.77s
# 4400:	learn: 0.3074354	total: 49s	remaining: 6.67s
# 4500:	learn: 0.3035809	total: 50.2s	remaining: 5.56s
# 4600:	learn: 0.2995916	total: 51.3s	remaining: 4.45s
# 4700:	learn: 0.2954536	total: 52.4s	remaining: 3.33s
# 4800:	learn: 0.2915716	total: 53.5s	remaining: 2.22s
# 4900:	learn: 0.2876190	total: 54.7s	remaining: 1.1s
# 4999:	learn: 0.2838900	total: 55.8s	remaining: 0us

# %%
from sklearn.metrics import accuracy_score, classification_report
print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6438
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63       776
#            1       0.65      0.66      0.66       824
#
#     accuracy                           0.64      1600
#    macro avg       0.64      0.64      0.64      1600
# weighted avg       0.64      0.64      0.64      1600

# %%
#Splitting Training data, 80% training, 20% testing
X_hold = holdout_set.drop(columns=target_column)
y_hold = holdout_set[target_column]

X_hold = X_hold.drop(columns=drop_cols, errors='ignore')
y_hold = y_hold.drop(columns=drop_cols, errors='ignore')

y_hold = y_hold.map({'1-0': 1, '0-1': 0, '1/2-1/2': -1})
# Make predictions on the holdout set
y_pred_hold = cat_model.predict(X_hold)

# Calculate the number of correct predictions and total predictions
correct_predictions = (y_pred_hold == y_hold).sum()
total_predictions = len(y_pred_hold)

# Output the results
print(f"Correct predictions: {correct_predictions} out of {total_predictions}, {correct_predictions/total_predictions}")
# Out:
# Correct predictions: 1278 out of 2000, 0.639

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import shap  # Import SHAP for explainability
from catboost import CatBoostRegressor, Pool
from sklearn.model_selection import KFold, cross_val_score, train_test_split
from sklearn.metrics import (
    mean_squared_error, r2_score, mean_absolute_error,
    confusion_matrix, ConfusionMatrixDisplay, accuracy_score,
    precision_score, recall_score, f1_score, roc_auc_score
)

# Cross-validation using K-Fold
kf = KFold(n_splits=5, shuffle=True, random_state=seed)
cv_scores = cross_val_score(cat_model, X_train, y_train, cv=kf, scoring="accuracy")

# Accuracy on the holdout set
accuracy = accuracy_score(y_hold, y_pred_hold)

# Precision, recall, F1-score
precision = precision_score(y_hold, y_pred_hold, average='weighted')
f1 = f1_score(y_hold, y_pred_hold, average='weighted')

# AUC-ROC for binary classification
auc_roc = roc_auc_score(y_hold, cat_model.predict_proba(X_hold)[:, 1])

metrics = {
    "Metric": ["Cross-Validation Accuracy", "Test Accuracy", "Precision", "F1 Score", "AUC-ROC"],
    "Value": [cv_scores.mean(), accuracy, precision, f1, auc_roc]
}

df = pd.DataFrame(metrics)
print(df.to_string(index=False))

# Get original feature importances and normalize them
feature_importances = cat_model.feature_importances_
normalized_importances = feature_importances / np.sum(feature_importances)

# Plot feature importances
plt.figure(figsize=(10, 6))
ax = sns.barplot(x=normalized_importances, y=X_train.columns, palette="viridis")

# Add annotations at the end of bars
for index, value in enumerate(normalized_importances):
    ax.text(value + 0.01, index, f"{value:.2f}", va="center")  # Adjust position slightly for normalized values

plt.title("Feature Importance (Normalized)")
plt.xlabel("Normalized Importance Score")
plt.ylabel("Feature")
plt.show()

# Compute confusion matrix
cm = confusion_matrix(y_hold, y_pred_hold)

# Create figure and axis
fig, ax = plt.subplots(figsize=(4, 4))

# Hide axes
ax.xaxis.set_visible(False) 
ax.yaxis.set_visible(False)
ax.set_frame_on(False)

# Create a table and add values
table = plt.table(cellText=cm, 
                  cellLoc='center', 
                  loc='center', 
                  rowLabels=["Actual 0", "Actual 1"], 
                  colLabels=["Pred 0", "Pred 1"])

table.scale(1, 2)  # Adjust size of cells

plt.title("Confusion Matrix (No Colors)")
plt.show()
# Out:
# 0:	learn: 0.6913231	total: 12.7ms	remaining: 1m 3s
# 100:	learn: 0.6169413	total: 994ms	remaining: 48.2s
# 200:	learn: 0.5949668	total: 1.99s	remaining: 47.5s
# 300:	learn: 0.5791178	total: 3s	remaining: 46.9s
# 400:	learn: 0.5660418	total: 4s	remaining: 45.9s
# 500:	learn: 0.5547923	total: 4.97s	remaining: 44.7s
# 600:	learn: 0.5438884	total: 5.92s	remaining: 43.3s
# 700:	learn: 0.5323400	total: 6.91s	remaining: 42.4s
# 800:	learn: 0.5213386	total: 7.88s	remaining: 41.3s
# 900:	learn: 0.5090643	total: 8.87s	remaining: 40.4s
# 1000:	learn: 0.4970568	total: 9.89s	remaining: 39.5s
# 1100:	learn: 0.4856289	total: 10.9s	remaining: 38.7s
# 1200:	learn: 0.4745610	total: 12s	remaining: 37.9s
# 1300:	learn: 0.4643872	total: 13s	remaining: 37s
# 1400:	learn: 0.4543703	total: 14.1s	remaining: 36.1s
# 1500:	learn: 0.4450423	total: 15.2s	remaining: 35.3s
# 1600:	learn: 0.4346336	total: 16.3s	remaining: 34.6s
# 1700:	learn: 0.4256481	total: 17.4s	remaining: 33.7s
# 1800:	learn: 0.4173429	total: 18.4s	remaining: 32.7s
# 1900:	learn: 0.4092255	total: 19.4s	remaining: 31.7s
# 2000:	learn: 0.4008927	total: 20.5s	remaining: 30.7s
# 2100:	learn: 0.3931763	total: 21.5s	remaining: 29.7s
# 2200:	learn: 0.3858323	total: 22.8s	remaining: 28.9s
# 2300:	learn: 0.3786915	total: 24s	remaining: 28.1s
# 2400:	learn: 0.3714783	total: 25.1s	remaining: 27.1s
# 2500:	learn: 0.3646980	total: 26.1s	remaining: 26.1s
# 2600:	learn: 0.3582797	total: 27.2s	remaining: 25.1s
# 2700:	learn: 0.3520978	total: 28.3s	remaining: 24.1s
# 2800:	learn: 0.3456392	total: 29.3s	remaining: 23s
# 2900:	learn: 0.3393316	total: 30.4s	remaining: 22s
# 3000:	learn: 0.3331530	total: 31.4s	remaining: 20.9s
# 3100:	learn: 0.3272064	total: 32.5s	remaining: 19.9s
# 3200:	learn: 0.3213849	total: 33.6s	remaining: 18.9s
# 3300:	learn: 0.3164523	total: 34.6s	remaining: 17.8s
# 3400:	learn: 0.3110019	total: 35.6s	remaining: 16.8s
# 3500:	learn: 0.3055689	total: 36.7s	remaining: 15.7s
# 3600:	learn: 0.3001779	total: 37.8s	remaining: 14.7s
# 3700:	learn: 0.2954054	total: 38.8s	remaining: 13.6s
# 3800:	learn: 0.2906292	total: 39.9s	remaining: 12.6s
# 3900:	learn: 0.2855939	total: 41s	remaining: 11.5s
# 4000:	learn: 0.2810954	total: 42s	remaining: 10.5s
# 4100:	learn: 0.2761726	total: 43.1s	remaining: 9.44s
# 4200:	learn: 0.2716879	total: 44.1s	remaining: 8.38s
# 4300:	learn: 0.2670346	total: 45.1s	remaining: 7.33s
# 4400:	learn: 0.2632242	total: 46.1s	remaining: 6.28s
# 4500:	learn: 0.2587462	total: 47.2s	remaining: 5.24s
# 4600:	learn: 0.2548569	total: 48.3s	remaining: 4.19s
# 4700:	learn: 0.2508616	total: 49.3s	remaining: 3.14s
# 4800:	learn: 0.2466120	total: 50.4s	remaining: 2.09s
# 4900:	learn: 0.2430310	total: 51.4s	remaining: 1.04s
# 4999:	learn: 0.2393537	total: 52.5s	remaining: 0us
# 0:	learn: 0.6915393	total: 12ms	remaining: 1m
# 100:	learn: 0.6206697	total: 1.01s	remaining: 48.8s
# 200:	learn: 0.5974733	total: 2.23s	remaining: 53.3s
# 300:	learn: 0.5823521	total: 3.44s	remaining: 53.7s
# 400:	learn: 0.5691458	total: 4.44s	remaining: 50.9s
# 500:	learn: 0.5569849	total: 5.41s	remaining: 48.6s
# 600:	learn: 0.5455661	total: 6.38s	remaining: 46.7s
# 700:	learn: 0.5345511	total: 7.4s	remaining: 45.4s
# 800:	learn: 0.5230218	total: 8.41s	remaining: 44.1s
# 900:	learn: 0.5110900	total: 9.42s	remaining: 42.8s
# 1000:	learn: 0.4999371	total: 10.5s	remaining: 41.8s
# 1100:	learn: 0.4888570	total: 11.5s	remaining: 40.9s
# 1200:	learn: 0.4774963	total: 12.6s	remaining: 39.9s
# 1300:	learn: 0.4662042	total: 13.7s	remaining: 39s
# 1400:	learn: 0.4561139	total: 14.8s	remaining: 38s
# 1500:	learn: 0.4465093	total: 15.9s	remaining: 37s
# 1600:	learn: 0.4375537	total: 16.9s	remaining: 35.9s
# 1700:	learn: 0.4286190	total: 18s	remaining: 34.9s
# 1800:	learn: 0.4202868	total: 19.1s	remaining: 33.9s
# 1900:	learn: 0.4121449	total: 20.2s	remaining: 33s
# 2000:	learn: 0.4036547	total: 21.3s	remaining: 31.9s
# 2100:	learn: 0.3954231	total: 22.4s	remaining: 31s
# 2200:	learn: 0.3874231	total: 23.6s	remaining: 30s
# 2300:	learn: 0.3801729	total: 24.6s	remaining: 28.9s
# 2400:	learn: 0.3731658	total: 25.7s	remaining: 27.8s
# 2500:	learn: 0.3662918	total: 26.8s	remaining: 26.8s
# 2600:	learn: 0.3593624	total: 27.9s	remaining: 25.7s
# 2700:	learn: 0.3524851	total: 28.9s	remaining: 24.6s
# 2800:	learn: 0.3458160	total: 30s	remaining: 23.6s
# 2900:	learn: 0.3397415	total: 31.1s	remaining: 22.5s
# 3000:	learn: 0.3340822	total: 32.2s	remaining: 21.4s
# 3100:	learn: 0.3287925	total: 33.3s	remaining: 20.4s
# 3200:	learn: 0.3220398	total: 34.6s	remaining: 19.4s
# 3300:	learn: 0.3161852	total: 35.8s	remaining: 18.4s
# 3400:	learn: 0.3106566	total: 36.9s	remaining: 17.3s
# 3500:	learn: 0.3053101	total: 37.9s	remaining: 16.2s
# 3600:	learn: 0.3001353	total: 39s	remaining: 15.2s
# 3700:	learn: 0.2948502	total: 40.1s	remaining: 14.1s
# 3800:	learn: 0.2897341	total: 41.2s	remaining: 13s
# 3900:	learn: 0.2851874	total: 42.2s	remaining: 11.9s
# 4000:	learn: 0.2805325	total: 43.3s	remaining: 10.8s
# 4100:	learn: 0.2762213	total: 44.4s	remaining: 9.74s
# 4200:	learn: 0.2719389	total: 45.5s	remaining: 8.65s
# 4300:	learn: 0.2678323	total: 46.6s	remaining: 7.57s
# 4400:	learn: 0.2633985	total: 47.7s	remaining: 6.49s
# 4500:	learn: 0.2591807	total: 48.7s	remaining: 5.4s
# 4600:	learn: 0.2550924	total: 49.8s	remaining: 4.32s
# 4700:	learn: 0.2508944	total: 50.8s	remaining: 3.23s
# 4800:	learn: 0.2469423	total: 51.9s	remaining: 2.15s
# 4900:	learn: 0.2429057	total: 53.1s	remaining: 1.07s
# 4999:	learn: 0.2391302	total: 54.1s	remaining: 0us
# 0:	learn: 0.6914690	total: 11.9ms	remaining: 59.4s
# 100:	learn: 0.6187300	total: 992ms	remaining: 48.1s
# 200:	learn: 0.5948958	total: 1.99s	remaining: 47.5s
# 300:	learn: 0.5782669	total: 3.02s	remaining: 47.1s
# 400:	learn: 0.5656913	total: 4.01s	remaining: 46s
# 500:	learn: 0.5537644	total: 5.02s	remaining: 45s
# 600:	learn: 0.5426307	total: 5.99s	remaining: 43.8s
# 700:	learn: 0.5301069	total: 6.97s	remaining: 42.7s
# 800:	learn: 0.5191846	total: 7.96s	remaining: 41.7s
# 900:	learn: 0.5071626	total: 9s	remaining: 40.9s
# 1000:	learn: 0.4966181	total: 10s	remaining: 40s
# 1100:	learn: 0.4856821	total: 11.1s	remaining: 39.2s
# 1200:	learn: 0.4758084	total: 12.4s	remaining: 39.1s
# 1300:	learn: 0.4649838	total: 13.5s	remaining: 38.4s
# 1400:	learn: 0.4547309	total: 14.6s	remaining: 37.5s
# 1500:	learn: 0.4452163	total: 15.6s	remaining: 36.5s
# 1600:	learn: 0.4359230	total: 16.7s	remaining: 35.5s
# 1700:	learn: 0.4265593	total: 17.8s	remaining: 34.5s
# 1800:	learn: 0.4178063	total: 18.9s	remaining: 33.6s
# 1900:	learn: 0.4088628	total: 20s	remaining: 32.6s
# 2000:	learn: 0.4010540	total: 21.1s	remaining: 31.6s
# 2100:	learn: 0.3930072	total: 22.1s	remaining: 30.5s
# 2200:	learn: 0.3852323	total: 23.2s	remaining: 29.5s
# 2300:	learn: 0.3779921	total: 24.3s	remaining: 28.5s
# 2400:	learn: 0.3705325	total: 25.4s	remaining: 27.5s
# 2500:	learn: 0.3626736	total: 26.5s	remaining: 26.5s
# 2600:	learn: 0.3554350	total: 27.6s	remaining: 25.4s
# 2700:	learn: 0.3489612	total: 28.7s	remaining: 24.4s
# 2800:	learn: 0.3429087	total: 29.7s	remaining: 23.3s
# 2900:	learn: 0.3356008	total: 30.8s	remaining: 22.3s
# 3000:	learn: 0.3294995	total: 31.9s	remaining: 21.2s
# 3100:	learn: 0.3234115	total: 33s	remaining: 20.2s
# 3200:	learn: 0.3174402	total: 34s	remaining: 19.1s
# 3300:	learn: 0.3114566	total: 35.1s	remaining: 18.1s
# 3400:	learn: 0.3058117	total: 36.3s	remaining: 17.1s
# 3500:	learn: 0.3002691	total: 37.4s	remaining: 16s
# 3600:	learn: 0.2948914	total: 38.6s	remaining: 15s
# 3700:	learn: 0.2898641	total: 39.9s	remaining: 14s
# 3800:	learn: 0.2846075	total: 41.1s	remaining: 13s
# 3900:	learn: 0.2796265	total: 42.3s	remaining: 11.9s
# 4000:	learn: 0.2744014	total: 43.6s	remaining: 10.9s
# 4100:	learn: 0.2699403	total: 45s	remaining: 9.87s
# 4200:	learn: 0.2653430	total: 46.2s	remaining: 8.79s
# 4300:	learn: 0.2607366	total: 47.4s	remaining: 7.71s
# 4400:	learn: 0.2562526	total: 48.8s	remaining: 6.63s
# 4500:	learn: 0.2523618	total: 50s	remaining: 5.54s
# 4600:	learn: 0.2481117	total: 51.3s	remaining: 4.44s
# 4700:	learn: 0.2438996	total: 52.5s	remaining: 3.34s
# 4800:	learn: 0.2397007	total: 53.8s	remaining: 2.23s
# 4900:	learn: 0.2357128	total: 55.1s	remaining: 1.11s
# 4999:	learn: 0.2317144	total: 56.2s	remaining: 0us
# 0:	learn: 0.6917020	total: 11.6ms	remaining: 57.9s
# 100:	learn: 0.6233998	total: 991ms	remaining: 48.1s
# 200:	learn: 0.5991377	total: 2.06s	remaining: 49.2s
# 300:	learn: 0.5835571	total: 3.08s	remaining: 48.1s
# 400:	learn: 0.5700209	total: 4.09s	remaining: 46.9s
# 500:	learn: 0.5571255	total: 5.08s	remaining: 45.6s
# 600:	learn: 0.5464207	total: 6.06s	remaining: 44.3s
# 700:	learn: 0.5351600	total: 6.99s	remaining: 42.9s
# 800:	learn: 0.5245313	total: 7.95s	remaining: 41.7s
# 900:	learn: 0.5146171	total: 8.95s	remaining: 40.7s
# 1000:	learn: 0.5045670	total: 9.97s	remaining: 39.8s
# 1100:	learn: 0.4923027	total: 11.1s	remaining: 39.2s
# 1200:	learn: 0.4823047	total: 12.1s	remaining: 38.4s
# 1300:	learn: 0.4722681	total: 13.2s	remaining: 37.5s
# 1400:	learn: 0.4620555	total: 14.3s	remaining: 36.6s
# 1500:	learn: 0.4533903	total: 15.3s	remaining: 35.7s
# 1600:	learn: 0.4449119	total: 16.4s	remaining: 34.8s
# 1700:	learn: 0.4354790	total: 17.4s	remaining: 33.8s
# 1800:	learn: 0.4276381	total: 18.5s	remaining: 32.9s
# 1900:	learn: 0.4193699	total: 19.8s	remaining: 32.2s
# 2000:	learn: 0.4117694	total: 21s	remaining: 31.5s
# 2100:	learn: 0.4041137	total: 22.1s	remaining: 30.5s
# 2200:	learn: 0.3965821	total: 23.1s	remaining: 29.4s
# 2300:	learn: 0.3893870	total: 24.2s	remaining: 28.4s
# 2400:	learn: 0.3816015	total: 25.3s	remaining: 27.3s
# 2500:	learn: 0.3742753	total: 26.3s	remaining: 26.3s
# 2600:	learn: 0.3675404	total: 27.4s	remaining: 25.3s
# 2700:	learn: 0.3613811	total: 28.5s	remaining: 24.3s
# 2800:	learn: 0.3551260	total: 29.6s	remaining: 23.2s
# 2900:	learn: 0.3489390	total: 30.7s	remaining: 22.2s
# 3000:	learn: 0.3428226	total: 31.8s	remaining: 21.2s
# 3100:	learn: 0.3368604	total: 32.9s	remaining: 20.1s
# 3200:	learn: 0.3307377	total: 33.9s	remaining: 19.1s
# 3300:	learn: 0.3250952	total: 35s	remaining: 18s
# 3400:	learn: 0.3196257	total: 36.1s	remaining: 17s
# 3500:	learn: 0.3139904	total: 37.2s	remaining: 15.9s
# 3600:	learn: 0.3084916	total: 38.2s	remaining: 14.9s
# 3700:	learn: 0.3035735	total: 39.3s	remaining: 13.8s
# 3800:	learn: 0.2985457	total: 40.4s	remaining: 12.7s
# 3900:	learn: 0.2934004	total: 41.5s	remaining: 11.7s
# 4000:	learn: 0.2883223	total: 42.6s	remaining: 10.6s
# 4100:	learn: 0.2836676	total: 43.7s	remaining: 9.57s
# 4200:	learn: 0.2793289	total: 44.7s	remaining: 8.51s
# 4300:	learn: 0.2752596	total: 45.8s	remaining: 7.44s
# 4400:	learn: 0.2709648	total: 46.9s	remaining: 6.38s
# 4500:	learn: 0.2668196	total: 48s	remaining: 5.32s
# 4600:	learn: 0.2620991	total: 49.1s	remaining: 4.25s
# 4700:	learn: 0.2578454	total: 50.1s	remaining: 3.19s
# 4800:	learn: 0.2536231	total: 51.4s	remaining: 2.13s
# 4900:	learn: 0.2496200	total: 52.6s	remaining: 1.06s
# 4999:	learn: 0.2459520	total: 53.7s	remaining: 0us
# 0:	learn: 0.6913551	total: 12.4ms	remaining: 1m 1s
# 100:	learn: 0.6155272	total: 969ms	remaining: 47s
# 200:	learn: 0.5934816	total: 1.94s	remaining: 46.3s
# 300:	learn: 0.5761877	total: 2.96s	remaining: 46.3s
# 400:	learn: 0.5607176	total: 3.95s	remaining: 45.3s
# 500:	learn: 0.5478544	total: 5.01s	remaining: 45s
# 600:	learn: 0.5350757	total: 6.01s	remaining: 44s
# 700:	learn: 0.5231660	total: 7.04s	remaining: 43.2s
# 800:	learn: 0.5114058	total: 8.03s	remaining: 42.1s
# 900:	learn: 0.4995428	total: 9.05s	remaining: 41.2s
# 1000:	learn: 0.4883522	total: 10.1s	remaining: 40.4s
# 1100:	learn: 0.4778750	total: 11.2s	remaining: 39.5s
# 1200:	learn: 0.4668661	total: 12.2s	remaining: 38.6s
# 1300:	learn: 0.4563006	total: 13.3s	remaining: 37.7s
# 1400:	learn: 0.4460088	total: 14.3s	remaining: 36.8s
# 1500:	learn: 0.4364041	total: 15.4s	remaining: 35.9s
# 1600:	learn: 0.4266854	total: 16.5s	remaining: 35.1s
# 1700:	learn: 0.4177944	total: 17.6s	remaining: 34.1s
# 1800:	learn: 0.4091889	total: 18.6s	remaining: 33.1s
# 1900:	learn: 0.4001807	total: 19.7s	remaining: 32.1s
# 2000:	learn: 0.3924730	total: 20.7s	remaining: 31.1s
# 2100:	learn: 0.3846516	total: 21.8s	remaining: 30s
# 2200:	learn: 0.3770505	total: 22.8s	remaining: 29s
# 2300:	learn: 0.3703351	total: 23.9s	remaining: 28s
# 2400:	learn: 0.3631439	total: 25s	remaining: 27.1s
# 2500:	learn: 0.3565640	total: 26.1s	remaining: 26.1s
# 2600:	learn: 0.3505033	total: 27.2s	remaining: 25.1s
# 2700:	learn: 0.3440020	total: 28.2s	remaining: 24s
# 2800:	learn: 0.3374101	total: 29.5s	remaining: 23.2s
# 2900:	learn: 0.3314480	total: 30.8s	remaining: 22.3s
# 3000:	learn: 0.3258792	total: 31.9s	remaining: 21.3s
# 3100:	learn: 0.3201785	total: 33.1s	remaining: 20.3s
# 3200:	learn: 0.3147920	total: 34.3s	remaining: 19.3s
# 3300:	learn: 0.3093590	total: 35.4s	remaining: 18.2s
# 3400:	learn: 0.3044160	total: 36.6s	remaining: 17.2s
# 3500:	learn: 0.2990430	total: 37.6s	remaining: 16.1s
# 3600:	learn: 0.2939471	total: 38.7s	remaining: 15s
# 3700:	learn: 0.2889016	total: 39.8s	remaining: 14s
# 3800:	learn: 0.2843375	total: 40.9s	remaining: 12.9s
# 3900:	learn: 0.2794637	total: 41.9s	remaining: 11.8s
# 4000:	learn: 0.2752871	total: 43.1s	remaining: 10.7s
# 4100:	learn: 0.2706618	total: 44.1s	remaining: 9.67s
# 4200:	learn: 0.2665002	total: 45.2s	remaining: 8.6s
# 4300:	learn: 0.2621818	total: 46.3s	remaining: 7.53s
# 4400:	learn: 0.2580580	total: 47.4s	remaining: 6.46s
# 4500:	learn: 0.2538977	total: 48.5s	remaining: 5.38s
# 4600:	learn: 0.2495702	total: 49.6s	remaining: 4.3s
# 4700:	learn: 0.2455456	total: 50.6s	remaining: 3.22s
# 4800:	learn: 0.2413858	total: 51.7s	remaining: 2.14s
# 4900:	learn: 0.2372559	total: 52.8s	remaining: 1.07s
# 4999:	learn: 0.2332561	total: 53.8s	remaining: 0us
#                    Metric    Value
# Cross-Validation Accuracy 0.635937
#             Test Accuracy 0.639000
#                 Precision 0.638916
#                  F1 Score 0.638942
#                   AUC-ROC 0.696105

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

# Get probability estimates for the positive class (class 1)
y_probs = cat_model.predict_proba(X_test)[:, 1]  # Assuming a binary classification problem

# Compute ROC curve and AUC
fpr, tpr, _ = roc_curve(y_test, y_probs)
roc_auc = auc(fpr, tpr)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', lw=2, label=f'ROC Curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')  # Random model baseline
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid()
plt.show()

# %%
import shap
import matplotlib.pyplot as plt

# Create SHAP explainer
explainer = shap.TreeExplainer(cat_model)

# Compute SHAP values
shap_values = explainer(X_hold)  # This returns an Explanation object

# Ensure SHAP values exist before plotting
if shap_values is not None:
    plt.figure(figsize=(10, 6))
    shap.plots.beeswarm(shap_values)
    #plt.title("SHAP Beeswarm Plot")
    plt.show()
else:
    print("SHAP values are empty! Check model predictions and input data.")
